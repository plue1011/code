# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.family'] = 'Times New Roman'

# %% [markdown]
# # 収束

# %%
simulation = pd.read_csv("./result/Epinions/PMC/simulation.csv")
simulation.head()
# Out:
#        inf_size
# 0  12327.000000
# 1  11894.500000
# 2  12075.666667
# 3  12064.000000
# 4  12074.600000

# %%
plt.rcParams['font.family'] = 'Times New Roman' # font familyの設定
plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.labelsize'] = 9 # 軸だけ変更されます。
plt.rcParams['ytick.labelsize'] = 9 # 軸だけ変更されます
plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid
plt.rcParams["legend.fancybox"] = False # 丸角
plt.rcParams["legend.framealpha"] = 1 # 透明度の指定、0で塗りつぶしなし
plt.rcParams["legend.edgecolor"] = 'black' # edgeの色を変更
plt.rcParams["legend.handlelength"] = 1 # 凡例の線の長さを調節
plt.rcParams["legend.labelspacing"] = 5. # 垂直方向の距離の各凡例の距離
plt.rcParams["legend.handletextpad"] = 1. # 凡例の線と文字の距離の長さ
plt.rcParams["legend.markerscale"] = 2 # 点がある場合のmarker scale
plt.rcParams["legend.borderaxespad"] = 0. # 凡例の端とグラフの端を合わせる
plt.rcParams['figure.dpi'] = 300 # 画質

x = list(range(1, len(simulation)+1))
y = simulation["inf_size"].to_list()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, y, color="b")

fig_1.set_xlabel(r"$simulation$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10000, 20000, 30000, 40000, 50000])
fig_1.set_yticks([11900, 12000, 12100, 12200, 12300])

#fig_1.legend(ncol=3, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/simulation.pdf', bbox_inches="tight", pad_inches=0.05)
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # HepPh

# %% [markdown]
# ## アルゴリズム

# %%
plt.rcParams['font.family'] = 'Times New Roman' # font familyの設定
plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.labelsize'] = 9 # 軸だけ変更されます。
plt.rcParams['ytick.labelsize'] = 9 # 軸だけ変更されます
plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid'] = True # make grid
plt.rcParams["legend.fancybox"] = False # 丸角
plt.rcParams["legend.framealpha"] = 1 # 透明度の指定、0で塗りつぶしなし
plt.rcParams["legend.edgecolor"] = 'black' # edgeの色を変更
plt.rcParams["legend.handlelength"] = 1 # 凡例の線の長さを調節
plt.rcParams["legend.labelspacing"] = 5. # 垂直方向の距離の各凡例の距離
plt.rcParams["legend.handletextpad"] = 1. # 凡例の線と文字の距離の長さ
plt.rcParams["legend.markerscale"] = 2 # 点がある場合のmarker scale
plt.rcParams["legend.borderaxespad"] = 0. # 凡例の端とグラフの端を合わせる
plt.rcParams['figure.dpi'] = 300 # 画質

# %% [markdown]
# ### lazy greedy

# %%
greedy_df = pd.read_csv("./result/HepPh/CEFL/spread.csv")
greedy_df.head()
# Out:
#          WC        TR   P=0_01
# 0    0.0000    0.0000   0.0000
# 1  352.5847   41.7878   6.0070
# 2  584.3262   75.1018  11.8598
# 3  763.8209  106.8549  16.6632
# 4  919.2136  137.9701  21.2590

# %%
x = greedy_df.index.tolist()
greedy_WC = greedy_df["WC"].tolist()
greedy_TR = greedy_df["TR"].tolist()
greedy_P001 = greedy_df["P=0_01"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, greedy_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, greedy_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="TR")
fig_1.plot(x, greedy_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000])

fig_1.legend(ncol=3, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/lazy_greedy_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMC

# %%
PMC_df = pd.read_csv("./result/HepPh/PMC/spread.csv")
PMC_df.head()
# Out:
#           WC        TR        P01     P001   P0001
# 0     0.0000    0.0000     0.0000   0.0000  0.0000
# 1   577.4052   74.4356  1235.8856  11.8852  2.7080
# 2   921.1256  136.6632  1786.9216  21.0532  5.1788
# 3  1177.6508  197.1476  2129.3856  29.8740  7.4156
# 4  1376.3796  244.9348  2398.8060  38.0620  9.8436

# %%
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ

x = [i for i in range(0, 51, 2)]
PMC_WC = PMC_df["WC"].tolist()
PMC_TR = PMC_df["TR"].tolist()
PMC_P01 = PMC_df["P01"].tolist()
PMC_P001 = PMC_df["P001"].tolist()
PMC_P0001 = PMC_df["P0001"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, PMC_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, PMC_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="TR")
fig_1.plot(x, PMC_P01, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="c", label="P=0.1")
fig_1.plot(x, PMC_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")
fig_1.plot(x, PMC_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="P=0.001")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/PMC_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### MIA

# %%
MIA_df = pd.read_csv("./result/HepPh/MIA/spread.csv")
MIA_df.head()
# Out:
#           WC        TR     P001   P0001
# 0     0.0000    0.0000   0.0000  0.0000
# 1   488.0452   72.5372  11.9548  2.0080
# 2   790.6316  134.4796  21.0440  4.0060
# 3  1030.4160  175.0432  30.1296  6.0112
# 4  1311.6984  228.9880  38.2560  8.0220

# %%
plt.rcParams["legend.labelspacing"] = 1. # 垂直方向の距離の各凡例の距離

x = [i for i in range(0, 51, 2)]
MIA_WC = MIA_df["WC"].tolist()
MIA_TR = MIA_df["TR"].tolist()
MIA_P001 = MIA_df["P001"].tolist()
MIA_P0001 = MIA_df["P0001"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, MIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, MIA_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="TR")
fig_1.plot(x, MIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")
fig_1.plot(x, MIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="P=0.001")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/MIA_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMIA

# %%
PMIA_df = pd.read_csv("./result/HepPh/PMIA/spread.csv")
PMIA_df.head()
# Out:
#           WC        TR     P001   P0001
# 0     0.0000    0.0000   0.0000  0.0000
# 1   488.0452   72.5372  11.9548  2.0080
# 2   629.3052  134.4796  21.0440  4.0060
# 3   959.3388  175.3212  30.1296  6.0112
# 4  1225.9364  228.3352  38.2560  8.0220

# %%
x = [i for i in range(0, 51, 2)]
PMIA_WC = PMIA_df["WC"].tolist()
PMIA_TR = PMIA_df["TR"].tolist()
PMIA_P001 = PMIA_df["P001"].tolist()
PMIA_P0001 = PMIA_df["P0001"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, PMIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, PMIA_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="TR")
fig_1.plot(x, PMIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")
fig_1.plot(x, PMIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="P=0.001")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/PMIA_HepPh.eps.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ## 伝搬確率モデル

# %% [markdown]
# ### WC

# %%
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ
x_1 = [i for i in range(0, 51, 2)]
x_2 = [i for i in range(0, 51)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_2, greedy_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="lazy greedy")
fig_1.plot(x_1, PMC_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, MIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="MIA")
fig_1.plot(x_1, PMIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/WC_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### TR

# %%
x_1 = [i for i in range(0, 51, 2)]
x_2 = [i for i in range(0, 51)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_2, greedy_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="lazy greedy")
fig_1.plot(x_1, PMC_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, MIA_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="MIA")
fig_1.plot(x_1, PMIA_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 200, 400, 600, 800])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/TR_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.1

# %%
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_P01, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000 ,2000, 3000, 4000, 5000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3)

# save
fig.savefig('./pic/P01_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.01

# %%
x_1 = [i for i in range(0, 51, 2)]
x_2 = [i for i in range(0, 51)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_2, greedy_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="lazy greedy")
fig_1.plot(x_1, PMC_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, MIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="MIA")
fig_1.plot(x_1, PMIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 50, 100, 150, 200])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/P001_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.001

# %%
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, MIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="MIA")
fig_1.plot(x_1, PMIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 20, 40, 60])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/P0001_HepPh.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# # Epinions

# %% [markdown]
# ## アルゴリズム

# %% [markdown]
# ### PMC

# %%
PMC_df = pd.read_csv("./result/Epinions/PMC/spread.csv")
PMC_df.head()
# Out:
#           WC         TR         P01      P001    P0001
# 0     0.0000     0.0000      0.0000    0.0000   0.0000
# 1  2470.0924  4082.2508  10329.3964  203.4464   5.6452
# 2  4009.8224  4103.3296  10339.4920  273.8692  10.5496
# 3  5150.2096  4127.8040  10351.3484  318.7612  14.5216
# 4  5855.8140  4143.1968  10362.2548  358.2812  18.3496

# %%
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ
x = [i for i in range(0, 51, 2)]
PMC_WC = PMC_df["WC"].tolist()
PMC_TR = PMC_df["TR"].tolist()
PMC_P01 = PMC_df["P01"].tolist()
PMC_P001 = PMC_df["P001"].tolist()
PMC_P0001 = PMC_df["P0001"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, PMC_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, PMC_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="g", label="TR")
fig_1.plot(x, PMC_P01, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="c", label="P=0.1")
fig_1.plot(x, PMC_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")
fig_1.plot(x, PMC_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="P=0.001")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 5000, 10000, 15000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/PMC_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMIA

# %%
PMIA_df = pd.read_csv("./result/Epinions/PMIA/spread.csv")
PMIA_df.head()
# Out:
#           WC      P001   P0001
# 0     0.0000    0.0000  0.0000
# 1  2447.1320  191.6920  2.2356
# 2  3999.1268  273.2392  4.3708
# 3  4999.6072  312.2156  6.4152
# 4  5834.8964  348.7208  8.7452

# %%
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ
x = [i for i in range(0, 51, 2)]
PMIA_WC = PMIA_df["WC"].tolist()
PMIA_P001 = PMIA_df["P001"].tolist()
PMIA_P0001 = PMIA_df["P0001"].tolist()

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x, PMIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="y", label="WC")
fig_1.plot(x, PMIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="P=0.01")
fig_1.plot(x, PMIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="P=0.001")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 4000, 8000, 12000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/PMIA_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ## 伝搬確率モデル

# %% [markdown]
# ### WC

# %%
plt.rcParams["legend.handletextpad"] = 2. # 凡例の線と文字の距離の長さ
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, PMIA_WC, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 5000, 10000, 15000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/WC_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### TR

# %%
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, PMIA_TR, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 1000, 2000, 3000, 4000, 5000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/TR_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.1

# %%
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_P01, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")

fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 5000, 10000])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3)

# save
fig.savefig('./pic/P01_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.01

# %%
x_1 = [i for i in range(0, 51, 2)]
x_2 = [i for i in range(0, 51)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, PMIA_P001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")


fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 200, 400, 600, 800])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/P001_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.001

# %%
x_1 = [i for i in range(0, 51, 2)]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.plot(x_1, PMC_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="r", label="PMC")
fig_1.plot(x_1, PMIA_P0001, marker='.', markersize=10, markeredgewidth=1., markeredgecolor='k', color="b", label="PMIA")

fig_1.set_xlabel(r"$k$")
fig_1.set_ylabel(r"$influence~spreads$")
# fig_1.set_xticklabels(np.round(x, 2), rotation=30)
fig_1.set_xticks([0, 10, 20, 30, 40, 50])
fig_1.set_yticks([0, 20, 40, 60, 80])

fig_1.legend(ncol=5, bbox_to_anchor=(0., 1.025, 1., 0.102), loc=3, mode='expand')

# save
fig.savefig('./pic/P0001_Epinions.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# # 実行時間

# %%
plt.rcParams['font.family'] = 'Times New Roman' # font familyの設定
plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.labelsize'] = 9 # 軸だけ変更されます。
plt.rcParams['ytick.labelsize'] = 9 # 軸だけ変更されます
plt.rcParams['xtick.direction'] = 'in' # x axis in
plt.rcParams['ytick.direction'] = 'in' # y axis in 
plt.rcParams['axes.linewidth'] = 1.0 # axis line width
plt.rcParams['axes.grid.axis'] = 'y' # make grid
plt.rcParams["legend.fancybox"] = False # 丸角
plt.rcParams["legend.framealpha"] = 1 # 透明度の指定、0で塗りつぶしなし
plt.rcParams["legend.edgecolor"] = 'black' # edgeの色を変更
plt.rcParams["legend.handlelength"] = 1 # 凡例の線の長さを調節
plt.rcParams["legend.labelspacing"] = 1. # 垂直方向の距離の各凡例の距離
plt.rcParams["legend.handletextpad"] = 0. # 凡例の線と文字の距離の長さ
plt.rcParams["legend.markerscale"] = 2 # 点がある場合のmarker scale
plt.rcParams["legend.borderaxespad"] = 0. # 凡例の端とグラフの端を合わせる
plt.rcParams['figure.dpi'] = 300 # 画質

# %% [markdown]
# ## HepPh

# %% [markdown]
# ## アルゴリズム

# %% [markdown]
# ### lazy greedy

# %%
greedy_df = pd.read_csv("./result/HepPh/CEFL/run_time.csv")
greedy_df
# Out:
#              WC             TR         P=0_01
# 0  1.000357e+06  359652.769107  101999.978196

# %%
x = ["WC", "TR", "P=0.01"]
y = greedy_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/greedy_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMC

# %%
PMC_df = pd.read_csv("./result/HepPh/PMC/run_time.csv")
PMC_df
# Out:
#             WC          TR        P=0_1      P=0_01     P=0_001
# 0  1310.788388  853.154843  4018.541926  546.008708  331.773296

# %%
x = ["WC", "TR", "P=0.1", "P=0.01", "P=0.001"]
y = PMC_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/PMC_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### MIA

# %%
MIA_df = pd.read_csv("./result/HepPh/MIA/run_time.csv")
MIA_df
# Out:
#             WC           TR         P=0_1      P=0_01   P=0_001
# 0  5262.052702  2295.073097  28853.175116  761.013551  9.199679

# %%
x = ["WC", "TR", "P=0.1", "P=0.01", "P=0.001"]
y = MIA_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/MIA_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMIA

# %%
PMIA_df = pd.read_csv("./result/HepPh/PMIA/run_time.csv")
PMIA_df
# Out:
#             WC           TR      P=0_01     P=0_001
# 0  1983.676722  1535.293857  928.507265  329.077298

# %%
x = ["WC", "TR", "P=0.01", "P=0.001"]
y = PMIA_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/PMIA_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ## 伝搬確率モデル

# %% [markdown]
# ### WC

# %%
x = ["lazy greedy", "PMC", "MIA", "PMIA"]
y = [greedy_df["WC"].values[0], PMC_df["WC"].values[0], MIA_df["WC"].values[0], PMIA_df["WC"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/WC_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %%
x = ["PMC", "MIA", "PMIA"]
y = [PMC_df["WC"].values[0], MIA_df["WC"].values[0], PMIA_df["WC"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/WC_HepPh_notgreedy_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### TR

# %%
x = ["lazy greedy", "PMC", "MIA", "PMIA"]
y = [greedy_df["TR"].values[0], PMC_df["TR"].values[0], MIA_df["TR"].values[0], PMIA_df["TR"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/TR_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %%
x = ["PMC", "MIA", "PMIA"]
y = [PMC_df["TR"].values[0], MIA_df["TR"].values[0], PMIA_df["TR"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/TR_HepPh_notgreedy_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.1

# %%
x = ["PMC"]
y = [PMC_df["P=0_1"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P01_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.01

# %%
x = ["lazy greedy","PMC", "MIA", "PMIA"]
y = [greedy_df["P=0_01"].values[0], PMC_df["P=0_01"].values[0], MIA_df["P=0_01"].values[0], PMIA_df["P=0_01"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P001_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %%
x = ["PMC", "MIA", "PMIA"]
y = [PMC_df["P=0_01"].values[0], MIA_df["P=0_01"].values[0], PMIA_df["P=0_01"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P001_HepPh_notgreedy_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.001

# %%
x = ["PMC", "MIA", "PMIA"]
y = [PMC_df["P=0_001"].values[0], MIA_df["P=0_001"].values[0], PMIA_df["P=0_001"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P0001_HepPh_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ## Epinions

# %% [markdown]
# ## アルゴリズム

# %% [markdown]
# ### PMC

# %%
PMC_df = pd.read_csv("./result/Epinions/PMC/run_time.csv")
PMC_df
# Out:
#             WC           TR        P=0_1       P=0_01    P=0_001
# 0  3648.358261  1095.244371  1406.393533  1052.205108  401.04686

# %%
x = ["WC", "TR", "P=0.1", "P=0.01", "P=0.001"]
y = PMC_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/PMC_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### PMIA

# %%
PMIA_df = pd.read_csv("./result/Epinions/PMIA/run_time.csv")
PMIA_df
# Out:
#              WC       P=0_01      P=0_001
# 0  12582.779663  8061.111132  2508.391381

# %%
x = ["WC", "P=0.01", "P=0.001"]
y = PMIA_df.values[0]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"spread model")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/PMIA_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ## 伝搬確率モデル

# %% [markdown]
# ### WC

# %%
x = ["PMC", "PMIA"]
y = [PMC_df["WC"].values[0], PMIA_df["WC"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/WC_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %%
x = ["PMC"]
y = [PMC_df["TR"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/TR_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %%
x = ["PMC"]
y = [PMC_df["P=0_1"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P01_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.01

# %%
x = ["PMC", "PMIA"]
y = [PMC_df["P=0_01"].values[0], PMIA_df["P=0_01"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P001_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)

# %% [markdown]
# ### P=0.001

# %%
x = ["PMC", "PMIA"]
y = [PMC_df["P=0_001"].values[0], PMIA_df["P=0_001"].values[0]]

# plot
fig = plt.figure()
fig_1 = fig.add_subplot(111)
fig_1.bar(x, y)

fig_1.set_xlabel(r"Algorithm")
fig_1.set_ylabel(r"running time[s]")

# save
fig.savefig('./pic/P0001_Epinions_time.pdf', bbox_inches="tight", pad_inches=0.05)
